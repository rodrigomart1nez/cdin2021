# %% [markdown]
# # Actividad 1

# %% [markdown]
# ### Utilizando el archivo [titanic.csv], realice lo que se le pide:

# %% [markdown]
# **1. Generar un DataFrame con los datos del fichero.**

# %%
# código aquí
import pandas as pd
import numpy as np

# %%
df_titanic = pd.read_csv('../Data/titanic.csv')

# %% [markdown]
# **2. Mostrar por pantalla las dimensiones del DataFrame, el número de datos que contiene, los nombres de sus columnas y filas, los tipos de datos de las columnas, las 10 primeras filas y las 10 últimas filas.**

# %%
# código aquí
#el número de datos que contiene
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# los nombres de sus columnas y filas

# %%
#  los tipos de datos de las columnas

# %%
# las 10 primeras filas y las 10 últimas filas
df_titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df_titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# **3. Mostrar por pantalla los datos del pasajero con identificador 148.**

# %%
# código aquí
df_titanic.loc[148]
# Out:
# PassengerId                                         149
# Survived                                              0
# Pclass                                                2
# Name           Navratil, Mr. Michel ("Louis M Hoffman")
# Sex                                                male
# Age                                                36.5
# SibSp                                                 0
# Parch                                                 2
# Ticket                                           230080
# Fare                                                 26
# Cabin                                                F2
# Embarked                                              S
# Name: 148, dtype: object

# %%
df_titanic[df_titanic['PassengerId']==148]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 147          148         0       3  Ford, Miss. Robina Maggie "Ruby"  female
#
#      Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 147  9.0      2      2  W./C. 6608  34.375   NaN        S

# %% [markdown]
# **4. Mostrar por pantalla las filas pares del DataFrame.**

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
df_titanic.shape
# Out:
# (891, 12)

# %%
# código aquí
df_titanic.iloc[range(0,df_titanic.shape[0], 2)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.iloc[0::2]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic[ df_titanic.index%2 == 0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **5. Mostrar por pantalla los nombres de las personas que iban en primera clase ordenadas alfabéticamente.**

# %%
# código aquí
df_titanic[df_titanic['Pclass']==1].sort_values(by='Name', ascending=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 730          731         1       1
# 305          306         1       1
# 297          298         0       1
# 498          499         0       1
# 460          461         1       1
# ..           ...       ...     ...
# 155          156         0       1
# 351          352         0       1
# 55            56         1       1
# 555          556         0       1
# 325          326         1       1
#
#                                                 Name     Sex    Age  SibSp  \
# 730                    Allen, Miss. Elisabeth Walton  female  29.00      0
# 305                   Allison, Master. Hudson Trevor    male   0.92      1
# 297                     Allison, Miss. Helen Loraine  female   2.00      1
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
# 460                              Anderson, Mr. Harry    male  48.00      0
# ..                                               ...     ...    ...    ...
# ...

# %%
df_titanic[df_titanic['Pclass']==1]['Name'].sort_values(ascending=True)
# Out:
# 730                      Allen, Miss. Elisabeth Walton
# 305                     Allison, Master. Hudson Trevor
# 297                       Allison, Miss. Helen Loraine
# 498    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 460                                Anderson, Mr. Harry
#                             ...
# 155                        Williams, Mr. Charles Duane
# 351             Williams-Lambert, Mr. Fletcher Fellows
# 55                                   Woolner, Mr. Hugh
# 555                                 Wright, Mr. George
# 325                           Young, Miss. Marie Grice
# Name: Name, Length: 216, dtype: object

# %% [markdown]
# **6. Mostrar por pantalla el porcentaje de personas que sobrevivieron y murieron.**

# %%
# código aquí
df_titanic['Survived'].sum()/(len(df_titanic))
# Out:
# 0.3838383838383838

# %%
((len(df_titanic)-1) - df_titanic['Survived'].sum())/(len(df_titanic))
# Out:
# 0.6150392817059483

# %%
df_titanic.shape[0]
# Out:
# 891

# %%
len(df_titanic)
# Out:
# 891

# %%
df_titanic.groupby('Survived').count()/(len(df_titanic))
# Out:
#           PassengerId    Pclass      Name       Sex       Age     SibSp  \
# Survived
# 0            0.616162  0.616162  0.616162  0.616162  0.475870  0.616162
# 1            0.383838  0.383838  0.383838  0.383838  0.325477  0.383838
#
#              Parch    Ticket      Fare     Cabin  Embarked
# Survived
# 0         0.616162  0.616162  0.616162  0.076319  0.616162
# 1         0.383838  0.383838  0.383838  0.152637  0.381594

# %%
df_titanic['Survived'].unique()
# Out:
# array([0, 1])

# %%
(df_titanic['Survived'].value_counts()/df_titanic['Survived'].count())*100
# Out:
# 0    61.616162
# 1    38.383838
# Name: Survived, dtype: float64

# %%
df_titanic['Survived'].count()
# Out:
# 891

# %% [markdown]
# **7. Mostrar por pantalla el porcentaje de personas que sobrevivieron en cada clase.**

# %%
# código aquí
df_titanic.groupby('Pclass')['Survived'].value_counts(normalize=True)
# Out:
# Pclass  Survived
# 1       1           0.655914
#         0           0.344086
# 2       0           0.520231
#         1           0.479769
# 3       0           0.760563
#         1           0.239437
# Name: Survived, dtype: float64

# %% [markdown]
# **8. Eliminar del DataFrame los pasajeros con edad desconocida.**

# %%
# código aquí
df_titanic.dropna(subset=['Age'], inplace=True)

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **9. Mostrar por pantalla la edad media de las mujeres que viajaban en cada clase.**

# %%
df_titanic.groupby(['Pclass','Sex'])['Age'].mean()
# Out:
# Pclass  Sex
# 1       female    34.611765
#         male      41.281386
# 2       female    28.722973
#         male      30.740707
# 3       female    21.750000
#         male      26.507589
# Name: Age, dtype: float64

# %%
# código aquí
df2 = df_titanic.groupby(['Pclass','Sex'])['Age'].mean().unstack()

# %%
df2
# Out:
# Sex        female       male
# Pclass
# 1       34.611765  41.281386
# 2       28.722973  30.740707
# 3       21.750000  26.507589

# %%
df2['female']
# Out:
# Pclass
# 1    34.611765
# 2    28.722973
# 3    21.750000
# Name: female, dtype: float64

# %% [markdown]
# **10.  Añadir una nueva columna booleana para ver si el pasajero era menor de edad o no.**

# %%
# código aquí
df_titanic['menor'] = df_titanic['Age']<18

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **11.  Mostrar por pantalla el porcentaje de menores y mayores de edad que sobrevivieron en cada clase.**

# %%
# código aquí
df_titanic.groupby(['Pclass', 'menor'])['Survived'].value_counts(normalize=True)*100
# Out:
# Pclass  menor  Survived
# 1       False  1           63.793103
#                0           36.206897
#         True   1           91.666667
#                0            8.333333
# 2       False  0           58.666667
#                1           41.333333
#         True   1           91.304348
#                0            8.695652
# 3       False  0           79.783394
#                1           20.216606
#         True   0           62.820513
#                1           37.179487
# Name: Survived, dtype: float64
