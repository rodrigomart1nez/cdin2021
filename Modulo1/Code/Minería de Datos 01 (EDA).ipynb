# %% [markdown]
# <h1><center>  Taxonomía de Datos </center></h1>
#
# Un dato es una representacion simbolica (numerica, alfabetica, algoritmica, espacial, etc.) de un atributo o variable cuantitativa o cualitativa. Los datos
# describen hechos empiricos, fenomenos y entidades. Tambien suele ser llamado
# dato a un valor que recibe una computadora por algun medio, los datos representan la informacion que el programador manipula en la construccion de una
# solucion o en el desarrollo de un algoritmo.
#
# ## Clasificacion de tipos de datos.
#
# Dentro de taxonomia numerica de los datos, se puede encontrar la siguiente
# clasificacion de la naturaleza de los datos para posibles caracterizaciones.
#
# ### Datos doble estado o binarios.
# Son obtenidos cuando solo presentan
# en la caracteristica evaluada dos posibilidades de respuesta, como ausencia o presencia de alguna caracteristica. Generalmente son codificadas
# como 0 para las negativas y 1 para las positivas. Presentan una distribucion estadistica binomial y el calculo de sus estadisticos basicos deben de
# realizarse con las formulas diseadas para esta distribucion
#
# ### Datos multi estado o cualitativos.
# Presentan mas de dos posibilidades
# de respuesta y pueden ser con secuencia logica o sin esta, es decir, este
# tipo de datos engloba a los estadisticos nominales (sin secuencia logica) y
# a los ordinales (con secuencia logica), cada uno de ellos con caracteristicas
# propias y metodos diseados para cada uno
#
# #### Datos nominales
# Son aquellos con mas de dos posibilidades de
# respuesta pero que no llevan un orden logico. Por ejemplo, a los
# colores se pueden asignar un numero a cada uno, es decir, rojo = 1,
# amarillo = 2, azul = 3, etc; sin embargo, no se puede concluir que
# rojo es menor que azul, son diferentes pero no en orden o secuencia
# logica.
#
# #### Datos ordinales.
# Pueden ser ordenados con una secuencia logica.
# Por ejemplo, al tamao de hoja se puede asignar un numero para
# designar que tan grande es, es decir, que puede ser chica = 1, mediana
# = 2, grande = 3. En este caso si se puede decir que grande es mas que
# chica o que la mediana aunque no de una manera cuantitativa. Estos
# datos cumplen generalmente con las distribuciones polinomiales u
# otras distribuciones derivadas de variables discretas. No obstante,
# datos ordinales y nominales son estadisticamente diferentes.
#
#
# ### Datos cuantitativos.
#
# Son datos que pueden contarse y que son continuos (presentan cualquier valor real); generalmente con una distribucion normal e incluso algunos datos discretos pueden ser utilizados con
# un buen muestreo, pero mediante estadisticos de tendencia central para
# obtener normalidad. Ejemplos de este tipo de datos pueden ser la altura
# de planta, peso de fruto y de semilla, cantidad de materia, numero de
# hojas, de frutos y de flores, entre otras (si el muestreo es adecuado)

# %%
import numpy as np

# %%
import pandas as pd

# %%
df_bank = pd.read_csv('../Data/bank.csv')

# %%
df_bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
df_bank['day'].unique()
# Out:
# array([19, 11, 16,  3,  5, 23, 14,  6, 17, 20, 13, 30, 29, 27,  7, 18, 12,
#        21, 26, 22,  2,  4, 15,  8, 28,  9,  1, 10, 31, 25, 24])

# %%
df_bank['age']
# Out:
# 0       30
# 1       33
# 2       35
# 3       30
# 4       59
#         ..
# 4516    33
# 4517    57
# 4518    57
# 4519    28
# 4520    44
# Name: age, Length: 4521, dtype: int64

# %%
df_bank['job'].unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
df_bank['month'].unique()
# Out:
# array(['oct', 'may', 'apr', 'jun', 'feb', 'aug', 'jan', 'jul', 'nov',
#        'sep', 'mar', 'dec'], dtype=object)

# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)

# %% [markdown]
# ## ¿Cuáles son los tipos de datos?
# ## ¿Se pueden manejar los datos faltantes? ¿Cómo?
# ## Realizar análisis estadístico de los datos
# ## Visualización de los datos
# ## Generar Insights

# %%
df_movie = pd.read_csv('../Data/movie_metadata.csv')

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
df_movie.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
df_movie.shape
# Out:
# (5043, 28)

# %% [markdown]
# ## Manejo de datos faltantes

# %%
df_movie_drop = df_movie.dropna()

# %%
df_movie_drop.shape
# Out:
# (3756, 28)

# %%
df_movie['duration'].min()
# Out:
# 7.0

# %%
df_movie['duration'].max()
# Out:
# 511.0

# %%
df_movie['duration']
# Out:
# 0       178.0
# 1       169.0
# 2       148.0
# 3       164.0
# 4         NaN
#         ...
# 5038     87.0
# 5039     43.0
# 5040     76.0
# 5041    100.0
# 5042     90.0
# Name: duration, Length: 5043, dtype: float64

# %%
df_movie.duration[190:200]
# Out:
# 190    147.0
# 191     90.0
# 192    101.0
# 193    138.0
# 194    107.0
# 195    142.0
# 196    165.0
# 197    100.0
# 198     82.0
# 199      NaN
# Name: duration, dtype: float64

# %%
df_movie['duration'] = df_movie['duration'].fillna(df_movie['duration'].mean())

# %%
df_movie['duration']
# Out:
# 0       178.000000
# 1       169.000000
# 2       148.000000
# 3       164.000000
# 4       107.201074
#            ...
# 5038     87.000000
# 5039     43.000000
# 5040     76.000000
# 5041    100.000000
# 5042     90.000000
# Name: duration, Length: 5043, dtype: float64

# %%
df_movie['duration'] = pd.Series(df_movie['duration'], dtype = 'int32')

# %%
df_movie['duration']
# Out:
# 0       178
# 1       169
# 2       148
# 3       164
# 4       107
#        ...
# 5038     87
# 5039     43
# 5040     76
# 5041    100
# 5042     90
# Name: duration, Length: 5043, dtype: int32

# %%
df_movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df_movie['title_year']
# Out:
# 0       2009.0
# 1       2007.0
# 2       2015.0
# 3       2012.0
# 4          NaN
#          ...
# 5038    2013.0
# 5039       NaN
# 5040    2013.0
# 5041    2012.0
# 5042    2004.0
# Name: title_year, Length: 5043, dtype: float64

# %%
df_movie['title_year'] = pd.to_datetime(df_movie['title_year'], format = '%Y')

# %%
df_movie['title_year']
# Out:
# 0      2009-01-01
# 1      2007-01-01
# 2      2015-01-01
# 3      2012-01-01
# 4             NaT
#           ...
# 5038   2013-01-01
# 5039          NaT
# 5040   2013-01-01
# 5041   2012-01-01
# 5042   2004-01-01
# Name: title_year, Length: 5043, dtype: datetime64[ns]

# %%
df_movie['movie_title']
# Out:
# 0                                                 Avatar
# 1               Pirates of the Caribbean: At World's End
# 2                                                Spectre
# 3                                  The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens    ...
#                               ...
# 5038                             Signed Sealed Delivered
# 5039                           The Following
# 5040                                A Plague So Pleasant
# 5041                                    Shanghai Calling
# 5042                                   My Date with Drew
# Name: movie_title, Length: 5043, dtype: object

# %%
df_movie['movie_title']= df_movie['movie_title'].str.upper()

# %%
df_movie['movie_title']
# Out:
# 0                                                 AVATAR
# 1               PIRATES OF THE CARIBBEAN: AT WORLD'S END
# 2                                                SPECTRE
# 3                                  THE DARK KNIGHT RISES
# 4       STAR WARS: EPISODE VII - THE FORCE AWAKENS    ...
#                               ...
# 5038                             SIGNED SEALED DELIVERED
# 5039                           THE FOLLOWING
# 5040                                A PLAGUE SO PLEASANT
# 5041                                    SHANGHAI CALLING
# 5042                                   MY DATE WITH DREW
# Name: movie_title, Length: 5043, dtype: object

# %%
df_movie['movie_title']= df_movie['movie_title'].str.lower()

# %%
df_movie['movie_title']
# Out:
# 0                                                 avatar
# 1               pirates of the caribbean: at world's end
# 2                                                spectre
# 3                                  the dark knight rises
# 4       star wars: episode vii - the force awakens    ...
#                               ...
# 5038                             signed sealed delivered
# 5039                           the following
# 5040                                a plague so pleasant
# 5041                                    shanghai calling
# 5042                                   my date with drew
# Name: movie_title, Length: 5043, dtype: object

# %%
df_movie.to_csv('../Data/clean_movie_df.csv')

# %% [markdown]
# ## Limpieza de los datos

# %% [markdown]
# ### Reporte de Calidad de los datos

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import string

# %%
def dqr(data):
    #%% Lista de variables de la base de datos
    columns = pd.DataFrame(list(data.columns.values),
                           columns= ['Nombres'],
                           index= list(data.columns.values)) 
    #%% Lista de tipos de datos
    data_types = pd.DataFrame(data.dtypes, columns=['Data_Types'])
    
    #%% lista de datos perdidos
    missing_values = pd.DataFrame(data.isnull().sum(),
                                  columns=['Missing_values'])
    #%% lista de valores presentes
    present_values = pd.DataFrame(data.count(), 
                                  columns=['Present Values'])
    
    #%% Lista de valores únicos para cada variable
    unique_values = pd.DataFrame(columns=['Unique_Values'])
    for col in list(data.columns.values):
        unique_values.loc[col] = [data[col].nunique()]

    #%% Lista de valores mínimos
    min_values = pd.DataFrame(columns=['Min'])
    for col in list(data.columns.values):
        try:
            min_values.loc[col] = [data[col].min()]
        except:
            pass
    
    #%% Lista de valores máximos
    max_values = pd.DataFrame(columns=['Max'])
    for col in list(data.columns.values):
        try:
            max_values.loc[col] = [data[col].max()]
        except:
            pass
    
    #%% Columna 'Categorica' que sea booleana que cuando sea True represente
    #   que la variable es categorica, y False represente que la variable es
    #  numérica
    return columns.join(data_types).join(missing_values).join(present_values).join(unique_values).join(min_values).join(max_values)

# %%
df_movie = pd.read_csv('../Data/movie_metadata.csv')

# %%
df_movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
list(df_movie.columns.values)
# Out:
# ['color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %%
for c in list(df_movie.columns.values):
        try:
            print(c)
            print(df_movie[c].max())
        except:
            pass
# Out:
# color
# director_name
# num_critic_for_reviews
# 813.0
# duration
# 511.0
# director_facebook_likes
# 23000.0
# actor_3_facebook_likes
# 23000.0
# actor_2_name
# actor_1_facebook_likes
# 640000.0
# gross
# 760505847.0
# genres
# Western
# actor_1_name
# movie_title
# Æon Flux
# num_voted_users
# 1689764
# cast_total_facebook_likes
# 656730
# actor_3_name
# facenumber_in_poster
# 43.0
# plot_keywords
# movie_imdb_link
# http://www.imdb.com/title/tt5574490/?ref_=fn_tt_tt_1
# num_user_for_reviews
# 5060.0
# language
# country
# content_rating
# budget
# 12215500000.0
# title_year
# 2016.0
# actor_2_facebook_likes
# 137000.0
# imdb_score
# 9.5
# aspect_ratio
# 16.0
# movie_facebook_likes
# 349000

# %%
reporte =dqr(df_movie)

# %%
reporte
# Out:
#                                              Nombres Data_Types  \
# color                                          color     object
# director_name                          director_name     object
# num_critic_for_reviews        num_critic_for_reviews    float64
# duration                                    duration    float64
# director_facebook_likes      director_facebook_likes    float64
# actor_3_facebook_likes        actor_3_facebook_likes    float64
# actor_2_name                            actor_2_name     object
# actor_1_facebook_likes        actor_1_facebook_likes    float64
# gross                                          gross    float64
# genres                                        genres     object
# actor_1_name                            actor_1_name     object
# movie_title                              movie_title     object
# num_voted_users                      num_voted_users      int64
# cast_total_facebook_likes  cast_total_facebook_likes      int64
# ...

# %% [markdown]
# ## EDA utilizando el reporte de Calidad Datos

# %%
vehicles = pd.read_csv('../Data/Vehicles_2015.csv')
accidents = pd.read_csv('../Data/Accidents_2015.csv')
casualties = pd.read_csv('../Data/Casualties_2015.csv')
# Out:
# /home/gaddiel/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
accidents
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       201501BS70001               525130.0                180050.0
# 1       201501BS70002               526530.0                178560.0
# 2       201501BS70004               524610.0                181080.0
# 3       201501BS70005               524420.0                181080.0
# 4       201501BS70008               524630.0                179040.0
# ...               ...                    ...                     ...
# 140051  2015984139115               312087.0                570791.0
# 140052  2015984139715               320671.0                569791.0
# 140053  2015984140215               311731.0                586343.0
# 140054  2015984140515               328273.0                570137.0
# 140055  2015984141415               314050.0                579638.0
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 0       -0.198465  51.505538             1                  3
# ...

# %%
reporte_accidentes = dqr(accidents)

# %%
reporte_accidentes
# Out:
#                                                                                  Nombres  \
# Accident_Index                                                            Accident_Index
# Location_Easting_OSGR                                              Location_Easting_OSGR
# Location_Northing_OSGR                                            Location_Northing_OSGR
# Longitude                                                                      Longitude
# Latitude                                                                        Latitude
# Police_Force                                                                Police_Force
# Accident_Severity                                                      Accident_Severity
# Number_of_Vehicles                                                    Number_of_Vehicles
# Number_of_Casualties                                                Number_of_Casualties
# ...

# %% [markdown]
# ### Crear un reporte de calidad de datos por cada dataset

# %% [markdown]
# ### En el dataset de accidentes
# 1.- Número de accidentes por fecha
#
# 2.- Número de vehículos accidentados por día
#
# 3.- Número de accidentados por fecha

# %%
# Número de accidentes por fecha
num_by_date = pd.DataFrame(pd.value_counts(accidents['Date']))
num_by_date
# Out:
#             Date
# 05/11/2015   535
# 02/10/2015   524
# 04/12/2015   520
# 13/11/2015   513
# 01/10/2015   510
# ...          ...
# 26/12/2015   231
# 11/01/2015   229
# 04/01/2015   214
# 28/12/2015   202
# 25/12/2015   180
#
# [365 rows x 1 columns]

# %%
accidents['Date'].value_counts()
# Out:
# 05/11/2015    535
# 02/10/2015    524
# 04/12/2015    520
# 13/11/2015    513
# 01/10/2015    510
#              ...
# 26/12/2015    231
# 11/01/2015    229
# 04/01/2015    214
# 28/12/2015    202
# 25/12/2015    180
# Name: Date, Length: 365, dtype: int64

# %%
#Número de vehículos accidentados por día
vehicles_day = pd.DataFrame(accidents.groupby(['Date'])
                            ['Number_of_Vehicles'].sum())

# %%
#  Número de accidentados por fecha
casualties_day = pd.DataFrame(accidents.groupby(['Date'])
                            ['Number_of_Casualties'].sum())

# %%
vehicles_day
# Out:
#             Number_of_Vehicles
# Date
# 01/01/2015                 402
# 01/02/2015                 399
# 01/03/2015                 445
# 01/04/2015                 616
# 01/05/2015                 742
# ...                        ...
# 31/05/2015                 503
# 31/07/2015                 860
# 31/08/2015                 533
# 31/10/2015                 659
# 31/12/2015                 584
#
# [365 rows x 1 columns]

# %%
casualties_day
# Out:
#             Number_of_Casualties
# Date
# 01/01/2015                   325
# 01/02/2015                   311
# 01/03/2015                   341
# 01/04/2015                   427
# 01/05/2015                   500
# ...                          ...
# 31/05/2015                   376
# 31/07/2015                   624
# 31/08/2015                   447
# 31/10/2015                   493
# 31/12/2015                   458
#
# [365 rows x 1 columns]

# %%
vehicles_casualties = num_by_date.join(vehicles_day).join(casualties_day)

# %%
vehicles_casualties
# Out:
#             Date  Number_of_Vehicles  Number_of_Casualties
# 05/11/2015   535                 973                   696
# 02/10/2015   524                1022                   691
# 04/12/2015   520                 930                   667
# 13/11/2015   513                 953                   683
# 01/10/2015   510                 948                   649
# ...          ...                 ...                   ...
# 26/12/2015   231                 393                   347
# 11/01/2015   229                 392                   295
# 04/01/2015   214                 361                   296
# 28/12/2015   202                 355                   265
# 25/12/2015   180                 309                   273
#
# [365 rows x 3 columns]

# %%
# Vehículos accidentados por días de la semana

accidents.groupby(['Day_of_Week'])['Number_of_Vehicles'].sum()
# Out:
# Day_of_Week
# 1    27385
# 2    37026
# 3    39747
# 4    39736
# 5    39815
# 6    41565
# 7    32571
# Name: Number_of_Vehicles, dtype: int64

# %%
accidents['Time']
# Out:
# 0         18:45
# 1         07:50
# 2         18:08
# 3         07:40
# 4         07:30
#           ...
# 140051    13:24
# 140052    13:50
# 140053    00:01
# 140054    12:40
# 140055    16:37
# Name: Time, Length: 140056, dtype: object

# %%
# A qué horas se tienen más vehículos accidentados?
vehicle_by_time = accidents.groupby(['Time'])['Number_of_Vehicles'].sum()

# %%
vehicle_by_time.argmax()
# Out:
# 1019

# %%
vehicle_by_time.sort_values(ascending=False, inplace=True)

# %%
vehicle_by_time
# Out:
# Time
# 17:00    2496
# 17:30    2468
# 18:00    2329
# 16:00    2267
# 16:30    2188
#          ...
# 02:48       3
# 04:37       3
# 02:41       3
# 04:34       2
# 04:04       2
# Name: Number_of_Vehicles, Length: 1439, dtype: int64

# %%
vehicle_by_time.argmax()
# Out:
# 0

# %%
vehicle_by_time.index[0]
# Out:
# '17:00'

# %%
# A qué horas se tienen más vehículos accidentados y en que día de la semana
vehicle_day_time = accidents.groupby(['Day_of_Week', 'Time'])['Number_of_Vehicles'].sum()

# %%
vehicle_day_time.argmax()
# Out:
# 6195

# %%
vehicle_day_time.index[6195]
# Out:
# (5, '17:00')

# %%
# En que lugar se tienen un mayor número de vehiculos accidentados?
vehicle_by_position = accidents.groupby(['Latitude', 'Longitude'])['Number_of_Vehicles'].sum()

# %%
vehicle_by_position.sort_values(ascending=False, inplace= True)

# %%
vehicle_by_position
# Out:
# Latitude   Longitude
# 51.875998  -1.200828    37
# 52.356499  -1.974701    16
# 51.389745  -0.188787    16
# 51.525200   0.169920    15
# 51.155227   0.259915    14
#                         ..
# 52.787472  -1.226540     1
# 51.777701   0.473350     1
# 52.787467  -1.314989     1
# 51.459668  -0.129016     1
# 60.661117  -1.046081     1
# Name: Number_of_Vehicles, Length: 136147, dtype: int64

# %% [markdown]
# # Visualización de las consultas

# %%
import matplotlib.pyplot as plt

# %%
# Mostrar la ubicación de los accidentes (latitud)
plt.hist(accidents['Latitude'][accidents['Latitude'].isnull()==False], bins=30)
plt.xlabel('Latitude')
plt.ylabel('Num_accidents')
plt.title('Histogram_accidents')
plt.show()

# %%
# Mostrar la ubicación de los accidentes (longitud)
plt.hist(accidents['Longitude'][accidents['Longitude'].isnull()==False], bins=30)
plt.xlabel('Longitude')
plt.ylabel('Num_accidents')
plt.title('Histogram_accidents')
plt.show()

# %%
plt.hist(accidents['Longitude'][accidents['Longitude'].isnull()==False], bins=30, color = 'r')
plt.hist(accidents['Latitude'][accidents['Latitude'].isnull()==False], bins=30, color='b')
plt.xlabel('Longitude')
plt.ylabel('Num_accidents')
plt.title('Histogram_accidents')
plt.show()

# %%
accidents_by_week = accidents.groupby(['Day_of_Week'])['Number_of_Vehicles'].sum()

# %%
accidents_by_week
# Out:
# Day_of_Week
# 1    27385
# 2    37026
# 3    39747
# 4    39736
# 5    39815
# 6    41565
# 7    32571
# Name: Number_of_Vehicles, dtype: int64

# %%
plt.hist(accidents_by_week)
# Out:
# (array([1., 0., 0., 1., 0., 0., 1., 0., 3., 1.]),
#  array([27385., 28803., 30221., 31639., 33057., 34475., 35893., 37311.,
#         38729., 40147., 41565.]),
#  <BarContainer object of 10 artists>)

# %%
a_w=accidents_by_week.reset_index()

# %%
a_w
# Out:
#    Day_of_Week  Number_of_Vehicles
# 0            1               27385
# 1            2               37026
# 2            3               39747
# 3            4               39736
# 4            5               39815
# 5            6               41565
# 6            7               32571

# %%
plt.hist(a_w['Day_of_Week'])
# Out:
# (array([1., 1., 0., 1., 0., 1., 1., 0., 1., 1.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
a_w['Number_of_Vehicles']
# Out:
# 0    27385
# 1    37026
# 2    39747
# 3    39736
# 4    39815
# 5    41565
# 6    32571
# Name: Number_of_Vehicles, dtype: int64
